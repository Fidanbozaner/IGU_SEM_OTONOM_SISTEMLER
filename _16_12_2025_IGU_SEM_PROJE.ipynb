# %% [markdown]
# 16.12.2025 İGÜ SEM Otonom Sistemler Eğitimi
# Fidan Bozaner
# Google Colab 1.örneği

# %%
print("Merhaba Hayat")
# Out:
# Merhaba Hayat
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %%
import sys
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/IGU_SEM_OTONOM')
# !pwd
# Out:
# /content/drive/My Drive/IGU_SEM_OTONOM
